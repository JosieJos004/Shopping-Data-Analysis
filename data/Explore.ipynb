# %% [markdown]
# Using pandas answer at least 4 of the 6 questions you wrote in the first part of your project. Include code to generate at least one data visualization or summary table as output, and 2-3 sentences of written interpretation of what you found.
#
# You are expected to use a variety of pandas operations in your notebook. You can use...
#
# groupby() to aggregate data across a categorical column.
#
# pivot_table() to summarize a relationship between two categorical variables.
#
# boolean filtering to isolate a subset of the data to answer a specific question.
#
# Your notebook should be readable from top to bottom, as if it was a short report. Use markdown cells to format your report to:
#
# title each section with the question you're investigating
# your interpretation after each output

# %%
import pandas as pd

import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/shopping.csv')

df.head()

df.info()

df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3510 non-null   float64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Purchase Amount (USD)   3900 non-null   float64
#  5   Location                3510 non-null   str
#  6   Size                    3900 non-null   str
#  7   Color                   3900 non-null   str
#  8   Season                  3900 non-null   str
#  9   Review Rating           1431 non-null   float64
#  10  Shipping Type           3900 non-null   str
#  11  Promo Code Used         3900 non-null   str
#  12  Previous Purchases      3900 non-null   int64
#  13  Payment Method          3900 non-null   str
#  14  Frequency of Purchases  1560 non-null   str
# ...

# %%
df.head()
# Out:
#    Customer ID   Age  Gender Item Purchased  Purchase Amount (USD)  Location  \
# 0         3475   NaN    Male         Jacket              30.904467     Maine
# 1         3698  21.0  Female       Backpack              31.588259       NaN
# 2         2756  31.0    Male       Leggings              24.231704    Nevada
# 3         3340   NaN    Male        Pajamas              33.918834  Nebraska
# 4         3391  38.0    Male     Sunglasses              36.545487    Oregon
#
#   Size         Color  Season  Review Rating Shipping Type Promo Code Used  \
# 0    M  Burnt orange    Fall            4.0      Standard              No
# 1    L     Turquoise  Winter            2.0       Express              No
# 2    M   Terra cotta  Winter            4.0      Standard              No
# 3    M         Black  Winter            NaN      Standard              No
# 4    S     Aubergine  Summer            NaN      Standard              No
#
# ...

# %%
df.pivot_table(values="Purchase Amount (USD)", index="Location", columns="Gender", aggfunc="mean")
# Out:
# Gender             Female       Male  Non-binary
# Location
# Alabama         37.078603  36.084544         NaN
# Alaska          35.369486  37.015142         NaN
# Arizona         36.266031  36.896224   36.876751
# Arkansas        41.494105  38.193216         NaN
# California      38.161198  38.567013   33.106153
# Colorado        39.589902  34.897295         NaN
# Connecticut     35.988479  35.129898         NaN
# Delaware        39.173337  38.671335   35.811128
# Florida         40.820284  39.890744         NaN
# Georgia         37.835086  38.694525         NaN
# Hawaii          42.640052  40.657137         NaN
# Idaho           40.141382  38.698120   28.379849
# Illinois        37.762948  36.936073         NaN
# Indiana         42.995251  43.861954         NaN
# Iowa            41.980723  41.847215   29.202617
# Kansas          34.667430  35.127604         NaN
# Kentucky        39.915698  35.359450   49.139632
# Louisiana       38.085553  39.703345   29.067419
# ...

# %%
def f(col): 
    return col.max() - col.min()

f = lambda col: col.max() - col.min()

# %%
df.groupby("Location")[["Review Rating", "Purchase Amount (USD)"]].agg(lambda col: col.max() - col.min())
# Out:
#                 Review Rating  Purchase Amount (USD)
# Location
# Alabama                   4.0              42.899896
# Alaska                    4.0              48.859351
# Arizona                   4.0              40.179193
# Arkansas                  3.0              41.803491
# California                3.0              43.316409
# Colorado                  4.0              46.488488
# Connecticut               4.0              45.622360
# Delaware                  3.0              50.313108
# Florida                   4.0              40.044420
# Georgia                   3.0              40.965594
# Hawaii                    1.0              45.015649
# Idaho                     3.0              52.324291
# Illinois                  3.0              43.283771
# Indiana                   3.0              40.268702
# Iowa                      4.0              45.435539
# Kansas                    4.0              38.681417
# ...

# %%
import pandas as pd

shopping_data = pd.read_csv("data/processed/shopping_cleaned.csv")

# %%
df.groupby("Gender")["Purchase Amount (USD)"].sum()
# Out:
# Gender
# Female        73620.710082
# Male          76032.285805
# Non-binary     1309.485399
# Name: Purchase Amount (USD), dtype: float64

# %%
# What gender buys the most by total number of orders?
df.groupby("Gender")["Frequency of Purchases"].count()
# Out:
# Gender
# Female        746
# Male          799
# Non-binary     15
# Name: Frequency of Purchases, dtype: int64

# %%
# On what items do the customers spend the most?
df["Item Purchased"].value_counts()
# Out:
# Item Purchased
# Shorts           314
# Sunglasses       312
# Running Shoes    309
# Dress            294
# Handbag          267
# T-shirt          262
# Sweater          231
# Leggings         228
# Backpack         225
# Gloves           217
# Pajamas          212
# Socks            211
# Hoodie           202
# Scarf            196
# Jacket           166
# Boots            166
# Jeans             54
# Belt              34
# Name: count, dtype: int64

# %%
# What item has the best review?
df.groupby("Item Purchased")["Review Rating"].value_counts()
# Out:
# Item Purchased  Review Rating
# Backpack        4.0              42
#                 5.0              29
#                 2.0              22
#                 1.0               2
# Belt            4.0              10
#                                  ..
# T-shirt         4.0              53
#                 5.0              31
#                 2.0              16
#                 1.0               3
#                 3.0               1
# Name: count, Length: 71, dtype: int64

# %%
# What size is purchased the most? 
df["Size"].value_counts()
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64
